# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
#import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code

html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-5abe724ecf200f8d9bbf52e5e4a2d7af.css" integrity="sha512-Wr5yTs8gD42bv1Ll5KLXr7cXzuVcbKOcuHmifgt/6YlZuluDTyAJnfnYhNYKpgVK1F51ks8Y2QA+XENQoMp/PA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.

tags= ["h1", 'p']

# %%
#2. Use BeautifulSoup to extract all the html elements that contain the developer names.

text = [element.text for element in soup.find_all(tags)]

text_head = text[:10]
text_head
# Out:
# ['Trending',
#  '\n      These are the developers building the hot tools today.\n    ',
#  '\n\n            Dotan Simha\n\n',
#  '\n\n              dotansimha\n\n',
#  '\n\n\n      graphql-code-generator\n\n',
#  '\n\n            Timothy Edmund Crosley\n\n',
#  '\n\n              timothycrosley\n\n',
#  '\n\n\n      isort\n\n',
#  '\n\n            Eliza Weisman\n\n',
#  '\n\n              hawkw\n\n']

# %%
#3. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. \n) 
#   in the text of each html element. Use a list to store the clean names.

def dev_names(lst):
    '''
    This function takes a list of strings.
    Filters the ones which has two skipline at the end of the string, which we're interested
    For each string, extracts only the words.
    If the string has just one word , we format it with (@word) and appends it to 'account'
    If the string has two words, joins them and appends resulting string to 'name'
    Then, creates a zip with name and account and appends it propery to a list
    '''
    name = []
    account = []
    devs = []
    for word in lst:
        
        # our useful info has \n\n at the end of the string
        if re.search('\n{2}$', word):  
            word = word.split()
            
            if len(word) == 1: 
                # 1 string means account
                word = '(@' + word[0] + ')'
                account.append(word)
                
            else:     
                word = ' '.join(word)
                name.append(word)
                
    for name, account in zip(name, account):
        info = name + ' ' + account
        devs.append(info)
        
    return devs
    
dev_name_user = dev_names(text)

# %%
#4. Print the list of names.
dev_name_user
# Out:
# ['Dotan Simha (@dotansimha)',
#  'Timothy Edmund Crosley (@graphql-code-generator)',
#  'Eliza Weisman (@timothycrosley)',
#  'Nick Cameron (@isort)',
#  'Toshiaki Maki (@hawkw)',
#  'Kamil Kisiela (@sharded-slab)',
#  'Giulio Canti (@nrc)',
#  'Stefan Prodan (@r4cppp)',
#  'Mikeal Rogers (@making)',
#  'Franck Nijhof (@yavi)',
#  'Nelson Osacky (@kamilkisiela)',
#  'Daniel Vaz Gaspar (@graphql-config)',
#  'Taylor Otwell (@gcanti)',
#  'Dave Anderson (@fp-ts)',
#  'Nathan Shively-Sanders (@stefanprodan)',
#  'Saleem Abdulrasool (@dockprom)',
#  'Benjamin Pasero (@mikeal)',
#  'Yannick Assogba (@r2)',
#  'Kirk Byers (@frenck)',
#  'Eugen Mayer (@awesome-home-assistant)',
#  'Sebastián Ramírez (@runningcode)',
#  'Limon Monte (@fladle)',
#  'Steven Kirk (@dpgaspar)',
#  'Jamie Hannaford (@Flask-AppBuilder)',
#  'Klaus Post (@taylorotwell)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-5abe724ecf200f8d9bbf52e5e4a2d7af.css" integrity="sha512-Wr5yTs8gD42bv1Ll5KLXr7cXzuVcbKOcuHmifgt/6YlZuluDTyAJnfnYhNYKpgVK1F51ks8Y2QA+XENQoMp/PA==" media="all" rel="stylesheet"/>
# ...

# %%
tags = 'h1'

text = [element.text for element in soup.find_all(tags)]

text_head = text[:10]
text
# Out:
# ['Trending',
#  '\n\n\n\n        pymatting /\n\n\n\n      pymatting\n\n',
#  '\n\n\n\n        microsoft /\n\n\n\n      DeepSpeed\n\n',
#  '\n\n\n\n        google-research /\n\n\n\n      text-to-text-transfer-transformer\n\n',
#  '\n\n\n\n        microsoft /\n\n\n\n      c9-python-getting-started\n\n',
#  '\n\n\n\n        bregman-arie /\n\n\n\n      devops-exercises\n\n',
#  '\n\n\n\n        Rlacat /\n\n\n\n      jd-automask\n\n',
#  '\n\n\n\n        huggingface /\n\n\n\n      transformers\n\n',
#  '\n\n\n\n        mingrammer /\n\n\n\n      diagrams\n\n',
#  '\n\n\n\n        getsentry /\n\n\n\n      sentry\n\n',
#  '\n\n\n\n        Netflix-Skunkworks /\n\n\n\n      riskquant\n\n',
#  '\n\n\n\n        public-apis /\n\n\n\n      public-apis\n\n',
#  '\n\n\n\n        edwardz246003 /\n\n\n\n      shadowsocks\n\n',
#  '\n\n\n\n        collinsmc23 /\n\n\n\n      python-keylogger-advanced\n\n',
#  '\n\n\n\n        PKSHATechnology-Research /\n\n\n\n      camphr\n\n',
# ...

# %%
def repo_names(lst):
    '''
    This function takes a list of strings.
    Filters the ones which has two skipline at the end of the string, which we're interested
    For each string, extracts only the words, and appends them into a list
    '''
    name = []
   
    for word in lst:
        
        # our useful info has \n\n at the end of the string
        if re.search('\n{2}$', word):  
            word = word.split()
            
            if len(word) == 1: 
                # 1 string means account
                word = '(@' + word[0] + ')'
                account.append(word)
                
            else:     
                word = ' '.join(word)
                name.append(word)
    
    return name

# %%
repo_names(text)
# Out:
# ['pymatting / pymatting',
#  'microsoft / DeepSpeed',
#  'google-research / text-to-text-transfer-transformer',
#  'microsoft / c9-python-getting-started',
#  'bregman-arie / devops-exercises',
#  'Rlacat / jd-automask',
#  'huggingface / transformers',
#  'mingrammer / diagrams',
#  'getsentry / sentry',
#  'Netflix-Skunkworks / riskquant',
#  'public-apis / public-apis',
#  'edwardz246003 / shadowsocks',
#  'collinsmc23 / python-keylogger-advanced',
#  'PKSHATechnology-Research / camphr',
#  'sqlmapproject / sqlmap',
#  'dragen1860 / Deep-Learning-with-TensorFlow-book',
#  'lucidrains / reformer-pytorch',
#  'lra / mackup',
#  'python-telegram-bot / python-telegram-bot',
#  'explosion / spaCy',
#  'IDSIA / sacred',
#  'MagicStack / uvloop',
#  'imcaspar / gpt2-ml',
#  'OpenMined / PySyft',
#  'thunil / TecoGAN']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = ['img']

# %%
text = [element['src'] for element in soup.find_all(tags)]

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = ['a']

# %%
text = [element for element in soup.find_all(tags, href=True)]

text
# Out:
# [<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/Python" title="wiktionary:Python">Python</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/python" title="wiktionary:python">python</a>,
#  <a href="#Snakes"><span class="tocnumber">1</span> <span class="toctext">Snakes</span></a>,
#  <a href="#Ancient_Greece"><span class="tocnumber">2</span> <span class="toctext">Ancient Greece</span></a>,
#  <a href="#Media_and_entertainment"><span class="tocnumber">3</span> <span class="toctext">Media and entertainment</span></a>,
#  <a href="#Computing"><span class="tocnumber">4</span> <span class="toctext">Computing</span></a>,
#  <a href="#Engineering"><span class="tocnumber">5</span> <span class="toctext">Engineering</span></a>,
#  <a href="#Roller_coasters"><span class="tocnumber">5.1</span> <span class="toctext">Roller coasters</span></a>,
# ...

# %%
def clean_url(lst):
    '''
    This function finds links on a list
    '''
    links = []
    for string in lst:
        string= str(string)
        words = re.split('[\s | ; | > |]', string)
        for word in words:
            if 'http' in word:
                links.append(word[6:])
    return links

# %%
clean_url(text)
# Out:
# ['https://en.wiktionary.org/wiki/Python"',
#  'https://en.wiktionary.org/wiki/python"',
#  'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&amp',
#  'https://en.wikipedia.org/w/index.php?title=Python&amp',
#  '//en.wikipedia.org/w/index.php?title=Python&amp',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452"',
#  'https://commons.wikimedia.org/wiki/Category:Python"',
#  'https://af.wikipedia.org/wiki/Python"',
#  'https://als.wikipedia.org/wiki/Python"',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86"',
#  'https://az.wikipedia.org/wiki/Python"',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)"',
#  'https://be.wikipedia.org/wiki/Python"',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = 'div'

# %%
text = [element.text for element in soup.find_all('div', class_= "usctitlechanged")]

text
# Out:
# ['\n\n          Title 18 - Crimes and Criminal Procedure ٭\n',
#  '\n\n          Title 20 - Education\n\n        ',
#  '\n\n          Title 26 - Internal Revenue Code\n\n        ']

# %%
titles = []

for string in text:
    string = string.replace('\n', ' ')
    string = string.split()
    string = ' '.join(string)
    titles.append(string)
    
titles
# Out:
# ['Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 20 - Education',
#  'Title 26 - Internal Revenue Code']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = 'h3'

# %%
text = [element.text for element in soup.find_all(tags)]

text
# Out:
# ['\nARNOLDO JIMENEZ\n',
#  '\nYASER ABDEL SAID\n',
#  '\nJASON DEREK BROWN\n',
#  '\nALEXIS FLORES\n',
#  '\nEUGENE PALMER\n',
#  '\nSANTIAGO VILLALBA MEDEROS\n',
#  '\nRAFAEL CARO-QUINTERO\n',
#  '\nROBERT WILLIAM FISHER\n',
#  '\nBHADRESHKUMAR CHETANBHAI PATEL\n',
#  '\nALEJANDRO ROSALES CASTILLO\n']

# %%
most_wanted = [string.replace('\n', '').title() for string in text]

most_wanted
# Out:
# ['Arnoldo Jimenez',
#  'Yaser Abdel Said',
#  'Jason Derek Brown',
#  'Alexis Flores',
#  'Eugene Palmer',
#  'Santiago Villalba Mederos',
#  'Rafael Caro-Quintero',
#  'Robert William Fisher',
#  'Bhadreshkumar Chetanbhai Patel',
#  'Alejandro Rosales Castillo']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = 'td'

# %%
datetime = [element.text for element in soup.find_all(tags, class_='tabev6')]
date = [string[:len(datetime)//2] for string in datetime]
time = [string[len(datetime)//2-2:] for string in datetime]

lat_alt = [str(element) for element in soup.find_all(tags, class_='tabev1')]
lat = lat_alt[::2]
alt = lat_alt[1::2]

region = [element.text for element in soup.find_all(tags, class_='tb_region')]

# %%
date_col = []

for value in date:
    a = value.split()
    date_col.append(a[0][10:])

time_col = [value[0:8] for value in time]

lat_col = [re.findall('\d{1,3}\.\d{2}', string)[0] for string in lat]
alt_col = [re.findall('\d{1,3}\.\d{2}', string)[0] for string in lat]

region_col = [string[1:].title() for string in region]
region_col
# Out:
# ['Salta, Argentina',
#  'Banda Sea',
#  'Island Of Hawaii, Hawaii',
#  'Eastern Turkey',
#  'Taiwan Region',
#  'Eastern Turkey',
#  'Eastern Turkey',
#  'Island Of Hawaii, Hawaii',
#  'Eastern Turkey',
#  'Hawaii Region, Hawaii',
#  'Kepulauan Barat Daya, Indonesia',
#  'Eastern Turkey',
#  'Offshore Coquimbo, Chile',
#  'Eastern Turkey',
#  'Poland',
#  'Flores Sea',
#  'Eastern Mediterranean Sea',
#  'Salta, Argentina',
#  'Puerto Rico',
#  'Eastern Turkey',
#  'Romania',
#  'Dodecanese Islands, Greece',
#  'Crete, Greece',
#  'Central Turkey',
#  'Andreanof Islands, Aleutian Is.',
#  'South Of Java, Indonesia',
#  'Western Turkey',
#  'Turkey-Iran Border Region',
#  'Southern Italy',
#  'Albania',
#  'Island Of Hawaii, Hawaii',
#  'Southern Italy',
#  'Rat Islands, Aleutian Islands',
#  'Eastern Turkey',
#  'Lesotho',
#  'Dodecanese Islands, Greece',
#  'Oklahoma',
#  'Leyte, Philippines',
#  'Central California',
#  'Puerto Rico Region',
#  'Kepulauan Aru Region, Indonesia',
# ...

# %%
cols = ['date', 'time', 'latitude', 'longitude', 'region name']

dictionary= {'date': date_col[:20],
            'time': time_col[:20],
            'latitude': lat_col[:20],
            'longitude': alt_col[:20],
            'region': region[:20]}

df = pd.DataFrame.from_dict(dictionary)

df
# Out:
#           date      time latitude longitude                            region
# 0   2020-02-13  18:32:23    24.06     24.06                  SALTA, ARGENTINA
# 1   2020-02-13  18:17:31     6.64      6.64                         BANDA SEA
# 2   2020-02-13  18:16:20    19.19     19.19          ISLAND OF HAWAII, HAWAII
# 3   2020-02-13  18:06:58    38.47     38.47                    EASTERN TURKEY
# 4   2020-02-13  17:49:18    24.25     24.25                     TAIWAN REGION
# 5   2020-02-13  17:40:49    38.46     38.46                    EASTERN TURKEY
# 6   2020-02-13  17:37:28    38.46     38.46                    EASTERN TURKEY
# 7   2020-02-13  17:34:34    19.22     19.22          ISLAND OF HAWAII, HAWAII
# 8   2020-02-13  17:28:45    38.47     38.47                    EASTERN TURKEY
# 9   2020-02-13  17:24:42    18.89     18.89             HAWAII REGION, HAWAII
# 10  2020-02-13  17:17:05     7.47      7.47   KEPULAUAN BARAT DAYA, INDONESIA
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')

# %%
tags = 'span'

# %%
span class="css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0"

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
