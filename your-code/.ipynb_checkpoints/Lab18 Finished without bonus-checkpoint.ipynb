# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = "https://github.com/trending/developers"

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-5abe724ecf200f8d9bbf52e5e4a2d7af.css" integrity="sha512-Wr5yTs8gD42bv1Ll5KLXr7cXzuVcbKOcuHmifgt/6YlZuluDTyAJnfnYhNYKpgVK1F51ks8Y2QA+XENQoMp/PA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
developers_tags =["h1","p"],{"class":["h3 lh-condensed","f4 text-normal mb-1"]}

# %%
developers_soup = soup.find_all(developers_tags)
developers_soup[0:8]
# Out:
# [<h1 class="h0-mktg">Trending</h1>, <p class="f4 text-gray col-md-10 mx-auto">
#        These are the developers building the hot tools today.
#      </p>, <h1 class="h3 lh-condensed">
#  <a href="/wkentaro">
#              Kentaro Wada
#  </a>
#  </h1>, <p class="f4 text-normal mb-1">
#  <a class="link-gray" href="/wkentaro">
#                wkentaro
#  </a>
#  </p>, <h1 class="h4 lh-condensed">
#  <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/wkentaro/labelme" style="max-width: 175px;">
#  <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#        labelme
#      </a>
# ...

# %%
clean_names = [developer.text.strip().replace(" ","").replace("\n\n", " ") for developer in developers_soup]
titles = clean_names[0:2]
repos = clean_names[:1:-3]
clean_names2 = [word for word in clean_names if word not in repos and word not in titles]
"\n".join(clean_names2)

list_of_names = []
for name in range(len(clean_names2)):
    if name % 2 == 0:
        string = clean_names2[name] + " (" + clean_names2[name+1] + ")"
        list_of_names.append(string)

# %%
list_of_names
# Out:
# ['KentaroWada (wkentaro)',
#  'EugenRochko (Gargron)',
#  'ArminRonacher (mitsuhiko)',
#  'ArvidNorberg (arvidn)',
#  'DavidFowler (davidfowl)',
#  'TimPope (tpope)',
#  'SamuelReed (STRML)',
#  'PaulusSchoutsen (balloob)',
#  'NavdeepGill (navdeep-G)',
#  'AhmadAlfy (ahmadalfy)',
#  'MaartenBreddels (maartenbreddels)',
#  'AymericAugustin (aaugustin)',
#  'PhilippeRémy (philipperemy)',
#  'AlexandruNedelcu (alexandru)',
#  'TimMeusel (bastelfreak)',
#  'GlebBahmutov (bahmutov)',
#  'KevinTitor (egoist)',
#  'FrankS.Thomas (fthomas)',
#  'Huan(李卓桓) (huan)',
#  'AdamGeitgey (ageitgey)',
#  'LukasTaegert-Atkinson (lukastaegert)',
#  'StefanoGottardo (CastagnaIT)',
#  'MartinKrasser (krasserm)',
#  '文翼 (wenzhixin)',
#  'KoenKanters (Koenkk)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-5abe724ecf200f8d9bbf52e5e4a2d7af.css" integrity="sha512-Wr5yTs8gD42bv1Ll5KLXr7cXzuVcbKOcuHmifgt/6YlZuluDTyAJnfnYhNYKpgVK1F51ks8Y2QA+XENQoMp/PA==" media="all" rel="stylesheet"/>
# ...

# %%
#your code
repo_tags =["h1","p"],{"class":["h3 lh-condensed","col-9 text-gray my-1 pr-4"]}

# %%
repo_soup = soup.find_all(repo_tags)
repo_soup[0:8]
# Out:
# [<h1 class="h0-mktg">Trending</h1>, <p class="f4 text-gray col-md-6 mx-auto">
#        See what the GitHub community is most excited about today.
#      </p>, <h1 class="h3 lh-condensed">
#  <a href="/domlysz/BlenderGIS">
#  <svg aria-label="repo" class="octicon octicon-repo mr-1 text-gray" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#  <span class="text-normal">
#          domlysz /
#  </span>
#
#
#        BlenderGIS
#  </a>
#  </h1>, <p class="col-9 text-gray my-1 pr-4">
#        Blender addons to make the bridge between Blender and geographic data
#      </p>, <h1 class="h3 lh-condensed">
#  <a href="/facebookresearch/pytorch3d">
# ...

# %%
clean_repo = [repo.text.strip().split('4">') for repo in repo_soup]
clean_repo2 = clean_repo[3::2]

# %%
clean_repo2
# Out:
# [['Blender addons to make the bridge between Blender and geographic data'],
#  ["PyTorch3D is FAIR's library of reusable components for deep learning with 3D data"],
#  ['code for Mesh R-CNN, an academic publication, presented at ICCV 2019'],
#  ['A collective list of free APIs for use in software and web development.'],
#  ['Firmware Analysis Tool'],
#  ['All Algorithms implemented in Python'],
#  ["The world's simplest facial recognition api for Python and the command line"],
#  ['Models and examples built with TensorFlow'],
#  ['fsociety Hacking Tools Pack – A Penetration Testing Framework'],
#  ['Magnificent app which corrects your previous console command.'],
#  ['京东监控口罩有货爬虫，自动下单爬虫，口罩爬虫'],
#  ['This repository is to help you to get Cloudflare VPN WARP+ 1.1.1.1 on your Desktop'],
#  ['The Python programming language'],
#  ['Command-line program to download videos from YouTube.com and other video sites'],
# ...

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

image_soup = soup.find_all("a", {"class":"image"})
image_soup[0:8]
# Out:
# [<a class="image" href="/wiki/File:Walt_Disney_1946.JPG"><img alt="Walt Disney 1946.JPG" data-file-height="675" data-file-width="450" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/330px-Walt_Disney_1946.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/440px-Walt_Disney_1946.JPG 2x" width="220"/></a>,
# ...

# %%
for link in image_soup:
    print(link["href"])
# Out:
# /wiki/File:Walt_Disney_1946.JPG
# /wiki/File:Walt_Disney_1942_signature.svg
# /wiki/File:Walt_Disney_envelope_ca._1921.jpg
# /wiki/File:Trolley_Troubles_poster.jpg
# /wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg
# /wiki/File:Steamboat-willie.jpg
# /wiki/File:Walt_Disney_1935.jpg
# /wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg
# /wiki/File:Disney_drawing_goofy.jpg
# /wiki/File:DisneySchiphol1951.jpg
# /wiki/File:WaltDisneyplansDisneylandDec1954.jpg
# /wiki/File:Walt_disney_portrait_right.jpg
# /wiki/File:Walt_Disney_Grave.JPG
# /wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg
# /wiki/File:Disney_Display_Case.JPG
# /wiki/File:Disney1968.jpg
# /wiki/File:The_Walt_Disney_Company_Logo.svg
# /wiki/File:Animation_disc.svg
# /wiki/File:P_vip.svg
# /wiki/File:Magic_Kingdom_castle.jpg
# /wiki/File:Video-x-generic.svg
# /wiki/File:Flag_of_Los_Angeles_County,_California.svg
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
links_soup = soup.find_all("a")


python_links = []
for href in links_soup:
    link = href.get("href")
    if link is not None:
        if link.startswith("http"):
            python_links.append(link)
python_links
# Out:
# ['https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0',
#  'https://en.wikipedia.org/w/index.php?title=Python&oldid=937840393',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452',
#  'https://commons.wikimedia.org/wiki/Category:Python',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86',
#  'https://az.wikipedia.org/wiki/Python',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#  'https://be.wikipedia.org/wiki/Python',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
txt = requests.get(url).text
changes = txt.count('class="usctitlechanged"')
print(changes)
# Out:
# 3

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
html = requests.get(url).content;
soup = BeautifulSoup(html, "lxml");
wanted_soup = soup.find_all("h3", {"class": "title"})
[wanted.text.strip() for wanted in wanted_soup]
# Out:
# ['YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,"lxml")
table = soup.find("tbody", {"id": "tbody"})

# %%
rows = table.find_all("tr")
rows
# Out:
# [<tr class="ligne1 normal" id="828500" onclick="go_details(event,828500);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=828500">2020-02-09   18:52:48.3</a></b><i class="ago" id="ago0">13min ago</i></td><td class="tabev1">19.20 </td><td class="tabev2">N  </td><td class="tabev1">155.41 </td><td class="tabev2">W  </td><td class="tabev3">32</td><td class="tabev5" id="magtyp0">Md</td><td class="tabev2">2.3</td><td class="tb_region" id="reg0"> ISLAND OF HAWAII, HAWAII</td><td class="comment updatetimeno" id="upd0" style="text-align:right;">2020-02-09 18:56</td></tr>,
# ...

# %%
earthquakes = []
    
for earthquake in rows:
    date, time = earthquake.find("td", {"class": "tabev6"}).find("a").text.split()
    latitude_degree, longitude_degree = earthquake.find_all("td", {"class": "tabev1"})
    latitude_cardinality, longitude_cardinality, magnitude = earthquake.find_all("td", {"class": "tabev2"})
    latitude = f"{latitude_degree.text.strip()} {latitude_cardinality.text.strip()}"
    longitude = f"{longitude_degree.text.strip()} {longitude_cardinality.text.strip()}"
    region = earthquake.find('td', {'class': 'tb_region'}).text.strip()
    results = [date, time, latitude, longitude, region]
    earthquakes.append(results)

# %%
colnames = ["Date", "Time", "Latitude", "Longitude", "Region"]

datos = earthquakes

earthquakeDF = pd.DataFrame(datos[:20], columns = colnames)

earthquakeDF
# Out:
#           Date        Time Latitude Longitude                           Region
# 0   2020-02-09  18:52:48.3  19.20 N  155.41 W         ISLAND OF HAWAII, HAWAII
# 1   2020-02-09  18:40:37.0  31.54 S   70.10 W              SAN JUAN, ARGENTINA
# 2   2020-02-09  18:29:35.0  22.40 S   68.63 W               ANTOFAGASTA, CHILE
# 3   2020-02-09  18:19:26.9  35.53 N  117.37 W              SOUTHERN CALIFORNIA
# 4   2020-02-09  18:19:23.0   2.74 S  129.87 E                 SERAM, INDONESIA
# 5   2020-02-09  18:10:07.5  19.22 N  155.42 W         ISLAND OF HAWAII, HAWAII
# 6   2020-02-09  17:56:55.8  19.19 N  155.46 W         ISLAND OF HAWAII, HAWAII
# 7   2020-02-09  17:56:28.0   0.91 S  120.27 E    MINAHASA, SULAWESI, INDONESIA
# 8   2020-02-09  17:49:34.0   7.30 S  107.54 E                  JAVA, INDONESIA
# 9   2020-02-09  17:45:25.0  39.07 N   27.81 E                   WESTERN TURKEY
# 10  2020-02-09  17:44:34.6  17.96 N   66.85 W                      PUERTO RICO
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
username = input()
html = requests.get(url + username).content
soup = BeautifulSoup(html, "lxml")

try:
    tweets_soup = soup.find("li", {"class":"ProfileNav-item ProfileNav-item--tweets is-active"})
    tweets = tweets_soup.find("a").find("span", {"class":"ProfileNav-value"})
    print("tweets: ",username, tweets.get("data-count"))
except:
    print("Doesn't match any existing account")
# Out:
# oscalaitexpats
# tweets:  oscalaitexpats 89

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
username = input()
html = requests.get(url + username).content
soup = BeautifulSoup(html, "lxml")

try:
    followers_soup = soup.find("li", {"class":"ProfileNav-item ProfileNav-item--followers"})
    followers = followers_soup.find("a").find("span", {"class":"ProfileNav-value"})
    print("followers: ",username, followers.get("data-count"))
except:
    print("Doesn't match any existing account")
# Out:
# oscalaitexpats
# followers:  oscalaitexpats 55

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

languages = soup.find_all("a", {"class": "link-box"})
language = [language.text.strip().split("\n") for language in languages]
language
# Out:
# [['English', '5\xa0994\xa0000+ articles'],
#  ['日本語', '1\xa0185\xa0000+ 記事'],
#  ['Deutsch', '2\xa0385\xa0000+ Artikel'],
#  ['Español', '1\xa0571\xa0000+ artículos'],
#  ['Русский', '1\xa0590\xa0000+ статей'],
#  ['Français', '2\xa0171\xa0000+ articles'],
#  ['Italiano', '1\xa0576\xa0000+ voci'],
#  ['中文', '1\xa0090\xa0000+ 條目'],
#  ['Português', '1\xa0018\xa0000+ artigos'],
#  ['Polski', '1\xa0379\xa0000+ haseł']]

# %%
type(language)
# Out:
# list

# %%
colnames = ["Language","Articles"]

df = pd.DataFrame(language, columns = colnames)
df
# Out:
#     Language              Articles
# 0    English   5 994 000+ articles
# 1        日本語         1 185 000+ 記事
# 2    Deutsch    2 385 000+ Artikel
# 3    Español  1 571 000+ artículos
# 4    Русский     1 590 000+ статей
# 5   Français   2 171 000+ articles
# 6   Italiano       1 576 000+ voci
# 7         中文         1 090 000+ 條目
# 8  Português    1 018 000+ artigos
# 9     Polski      1 379 000+ haseł

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html,"lxml")
kinds_of_datasets = soup.find_all("h2")
for dataset in kinds_of_datasets:
    print(dataset.text)
# Out:
# Business and economy
# Crime and justice
# Defence
# Education
# Environment
# Government
# Government spending
# Health
# Mapping
# Society
# Towns and cities
# Transport

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html,"lxml")
table = soup.find_all("table", {"class":"wikitable sortable"})[0]
rows = table.find_all("tr")
rows = [row.text.strip().split("\n") for row in rows]
rows = [list(filter(None,row)) for row in rows]
rows
# Out:
# [['Rank',
#   'Language',
#   'Speakers(millions)',
#   '% of the World population',
#   '(March 2019)[8]',
#   'Language familyBranch'],
#  ['1', 'Mandarin Chinese', '918', '11.922', 'Sino-TibetanSinitic'],
#  ['2', 'Spanish', '480', '5.994', 'Indo-EuropeanRomance'],
#  ['3', 'English', '379', '4.922', 'Indo-EuropeanGermanic'],
#  ['4',
#   'Hindi (Sanskritised Hindustani)[9]',
#   '341',
#   '4.429',
#   'Indo-EuropeanIndo-Aryan'],
#  ['5', 'Bengali', '228', '2.961', 'Indo-EuropeanIndo-Aryan'],
#  ['6', 'Portuguese', '221', '2.870', 'Indo-EuropeanRomance'],
#  ['7', 'Russian', '154', '2.000', 'Indo-EuropeanBalto-Slavic'],
#  ['8', 'Japanese', '128', '1.662', 'JaponicJapanese'],
#  ['9', 'Western Punjabi[10]', '92.7', '1.204', 'Indo-EuropeanIndo-Aryan'],
#  ['10', 'Marathi', '83.1', '1.079', 'Indo-EuropeanIndo-Aryan'],
#  ['11', 'Telugu', '82.0', '1.065', 'DravidianSouth-Central'],
#  ['12', 'Wu Chinese', '81.4', '1.057', 'Sino-TibetanSinitic'],
# ...

# %%
#colnames = rows['Rank','Language','Speakers(millions)','% of the World population','Language familyBranch']

df = pd.DataFrame(rows[1:])
df
# Out:
#      0                                   1     2       3  \
# 0    1                    Mandarin Chinese   918  11.922
# 1    2                             Spanish   480   5.994
# 2    3                             English   379   4.922
# 3    4  Hindi (Sanskritised Hindustani)[9]   341   4.429
# 4    5                             Bengali   228   2.961
# ..  ..                                 ...   ...     ...
# 86  87                               Czech  10.7   0.139
# 87  88                Taʽizzi-Adeni Arabic  10.5   0.136
# 88  89                              Uyghur  10.4   0.135
# 89  90                    Min Dong Chinese  10.3   0.134
# 90  91                             Sylheti  10.3   0.134
#
#                             4
# 0         Sino-TibetanSinitic
# 1        Indo-EuropeanRomance
# 2       Indo-EuropeanGermanic
# 3     Indo-EuropeanIndo-Aryan
# 4     Indo-EuropeanIndo-Aryan
# ..                        ...
# 86  Indo-EuropeanBalto-Slavic
# ...

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df=df.drop([0,3,4], axis=1)

# %%
df = df.rename(columns={1:"Language",
                            2: "Millions of speakers"})
df.columns
# Out:
# Index(['Language', 'Millions of speakers'], dtype='object')

# %%
df
# Out:
#                               Language Millions of speakers
# 0                     Mandarin Chinese                  918
# 1                              Spanish                  480
# 2                              English                  379
# 3   Hindi (Sanskritised Hindustani)[9]                  341
# 4                              Bengali                  228
# ..                                 ...                  ...
# 86                               Czech                 10.7
# 87                Taʽizzi-Adeni Arabic                 10.5
# 88                              Uyghur                 10.4
# 89                    Min Dong Chinese                 10.3
# 90                             Sylheti                 10.3
#
# [91 rows x 2 columns]

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
